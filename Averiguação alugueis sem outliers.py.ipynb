# %%
import pandas as pd
import numpy as np

# %%
matriz = pd.read_csv('aluguel_residencial_sem_outliers.csv', sep = ';')

# %%
matriz
# Out:
#               Tipo          Bairro  Quartos  Vagas  Suites   Area    Valor  \
# 0      Apartamento          Centro        1      0       0     15    800.0
# 1      Apartamento    Higienópolis        1      0       0     48    800.0
# 2      Apartamento    Vista Alegre        3      1       0     70   1200.0
# 3      Apartamento        Cachambi        2      0       0     50   1300.0
# 4      Apartamento          Centro        1      0       0     36   1200.0
# ...            ...             ...      ...    ...     ...    ...      ...
# 20818        Sítio           Lagoa        6      0       2    750  15000.0
# 20819        Sítio  Vargem Pequena        2      0       0   2900   8000.0
# 20820        Sítio         Camorim        8      0       7  32000  15000.0
# 20821        Sítio         Camorim        8      0       7  42000  20000.0
# 20822        Sítio         Camorim        8      0       7  32000  15000.0
#
#        Condominio     IPTU  Valor Bruto  Media m2 Tipo agregado
# ...

# %%
matriz['Bairro'].drop_duplicates()
# Out:
# 0                Centro
# 1          Higienópolis
# 2          Vista Alegre
# 3              Cachambi
# 5                Grajaú
#               ...
# 18055           Paquetá
# 18175    Senador Camará
# 19216        Cachamorra
# 19493      Rio da Prata
# 19832      Vila Militar
# Name: Bairro, Length: 153, dtype: object

# %%
x = matriz['Bairro'].unique()

# %%
len(x)
# Out:
# 153
